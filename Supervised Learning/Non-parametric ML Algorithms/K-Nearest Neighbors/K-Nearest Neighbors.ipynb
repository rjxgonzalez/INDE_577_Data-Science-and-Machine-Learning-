# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

sns.set_theme()

data = pd.read_csv("Gender Classification.csv") # Reading in the Gender Classification dataset

# %%
data
# Out:
#       long_hair  Forehead Width (cm)  Forehead Height (cm)  nose_wide  \
# 0             0                 14.0                   5.4          0
# 1             1                 13.5                   5.9          0
# 2             0                 13.0                   5.2          0
# 3             1                 11.9                   5.4          1
# 4             1                 12.1                   5.4          0
# ...         ...                  ...                   ...        ...
# 4996          1                 12.1                   6.2          1
# 4997          1                 14.1                   7.0          1
# 4998          1                 12.9                   7.0          1
# 4999          1                 12.3                   6.9          0
# 5000          1                 15.4                   5.4          1
#
#       nose_long  lips_thin  distance_nose_to_lip_long  Gender
# 0             0          1                          0  Female
# 1             0          0                          0  Female
# 2             0          0                          0  Female
# 3             0          1                          1  Female
# 4             0          0                          0  Female
# ...         ...        ...                        ...     ...
# 4996          1          1                          1    Male
# 4997          1          1                          1    Male
# 4998          1          1                          1    Male
# 4999          1          1                          1    Male
# 5000          1          1                          1    Male
#
# [5001 rows x 8 columns]

# %%
female_w = data.iloc[:100]["Forehead Width (cm)"] # storing the width feature measurement of the first 100 rows (females)
female_h = data.iloc[:100]["Forehead Height (cm)"] # storing the height feature measurement of the first 100 rows (females)

male_w = data.tail(100)["Forehead Width (cm)"]    # storing the width feature measurement of the last 100 rows (males)
male_h= data.tail(100)["Forehead Height (cm)"]    # storing the height feature measurement of the last 100 rows (males)

# %%
# Plot the data
gender = ["Male","Female"]
colors = ["red", "lightseagreen"]

fig, ax = plt.subplots(figsize = (10, 8))
for gender, color in zip(gender, colors):
    temp_df = data[data.Size == sizes]

    ax.scatter(temp_df["Weight (cm)"].iloc[:150].values,
               temp_df["Height (cm)"].iloc[:150].values ,
               c = color,
               label = sizes, 
               )
    
ax.set_xlabel("Height (cm)", fontsize = 15)
ax.set_ylabel("Weight (kg)", fontsize = 15)
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\gonza\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\gonza\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\gonza\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weight (cm)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15996/407580406.py in <module>
#       7     temp_df = data[data.Size == sizes]
#       8
# ----> 9     ax.scatter(temp_df["Weight (cm)"].iloc[:150].values,
#      10                temp_df["Height (cm)"].iloc[:150].values ,
#      11                c = color,
#
# c:\Users\gonza\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\gonza\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Weight (cm)'
